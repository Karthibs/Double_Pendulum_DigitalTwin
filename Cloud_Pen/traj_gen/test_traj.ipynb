# %%
from tet_traj import generate_all

# %%
generate_all(out_dir='test_trajs', plot=True)
# Out:
#   T01                        peak_q=(2.15, 0.70)  peak_v=(5.65, 3.14) rad/s  -> test_trajs/T01.csv
#   T02                        peak_q=(0.80, 0.60)  peak_v=(10.04, 7.53) rad/s  -> test_trajs/T02.csv
#   T03                        peak_q=(0.70, 0.70)  peak_v=(2.20, 2.20) rad/s  -> test_trajs/T03.csv
#   T04                        peak_q=(0.60, 0.60)  peak_v=(1.51, 2.26) rad/s  -> test_trajs/T04.csv
#   T05                        peak_q=(0.80, 0.80)  peak_v=(5.03, 5.03) rad/s  -> test_trajs/T05.csv
#   T06                        peak_q=(0.70, 0.50)  peak_v=(1.32, 1.88) rad/s  -> test_trajs/T06.csv
#   T07                        peak_q=(0.60, 0.60)  peak_v=(2.26, 2.26) rad/s  -> test_trajs/T07.csv
#   T08                        peak_q=(0.67, 0.48)  peak_v=(0.66, 0.47) rad/s  -> test_trajs/T08.csv
#   T09                        peak_q=(0.60, 0.40)  peak_v=(0.97, 0.80) rad/s  -> test_trajs/T09.csv
# ...

# %%
from stress_traj import generate_all

# %%
generate_all(out_dir='stress_trajs', plot=True)
# Out:
# name                           peak_q1   peak_q2   peak_v1   peak_v2   peak_a1   peak_a2  safety
# ----------------------------------------------------------------------------------------------------
#   S01                            1.400     1.400      1.76      1.76       2.2       2.2  OK
#   S02                            1.200     1.000      4.52      3.77      17.1      14.2  OK
#   S03                            1.000     0.800      9.17      7.50      87.0      68.0  OK
#   S04                            1.500     1.000      3.77      2.51       9.5      16.3  OK
#   S05                            1.200     1.000      1.62      1.35       2.9       2.4  OK
#   S06                            3.042     0.800      0.94      0.63       3.9       3.1  OK
#   S07                            0.500     0.525      6.06      5.91      98.3     106.4  OK
#   S08                            1.000     1.000      4.40      3.46      19.3      11.9  OK
# ...
